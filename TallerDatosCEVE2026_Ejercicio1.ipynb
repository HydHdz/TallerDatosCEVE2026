# %% [markdown]
# CONCURSO DE ESTANCIAS DE VERANO EXPERIMENTALES 2026
#
# # TALLER DE ANÁLISIS DE DATOS
#
# # EJERCICIO 1 - GRAFICAR E INTERPRETAR

# %% [markdown]
# ## Datos a analizar
#
# Los archivos que analizaremos corresponden a datos recolectados en 2011:
#
# CMS collaboration (2016). DoubleMu primary dataset in AOD format from RunA of 2011 (/DoubleMu/Run2011A-12Oct2013-v1/AOD). CERN Open Data Portal. DOI: 10.7483/OPENDATA.CMS.RZ34.QR6N.
#
# La selección de eventos se realizó utilizando el código que puede encontrarse en: https://github.com/tpmccauley/dimuon-filter
#
#
#
# Primero descargamos los datos:

# %%
# !wget "https://raw.githubusercontent.com/cms-opendata-education/cms-jupyter-materials-english/refs/heads/master/Data/Zmumu_Run2011A.csv"
# !wget "https://raw.githubusercontent.com/cms-opendata-education/cms-jupyter-materials-english/refs/heads/master/Data/Zee_Run2011A.csv"

# %% [markdown]
# ## Paquetes requeridos

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import math as m
# %matplotlib inline

# %% [markdown]
# ## Z -> mu mu

# %%
# Extraemos los datos y los convertimos en un DataFrame

zmumu = pandas.read_csv('Zmumu_Run2011A.csv')

zmumu.head()

# %%
# Utilice la función "describe()" para obtener los estadísticos de los datos
# ¿Qué puede concluir?

# %%
# Graficando Phi
# Visualice la distribución de la variable "phi" de ambos muones. 
# ¿Qué puede concluir?

plt.hist(zmumu['phi1'], bins=50, color = 'blue',alpha=1, hatch='/',range=(-4,4))
plt.hist(zmumu['phi2'],bins=50, color='red', alpha=0.5, hatch='||', range=(-4,4))
plt.show()

# %% [markdown]
# ### EJERCICIO 1 a):
#
# - De igual forma, grafique la variable "pt". ¿Qué puede concluir?
# - Grafique ahora la variable "Eta". ¿Qué puede concluir?
# - Utilice la fórmula vista en el taller para calcular la masa invariante del sistema de dos muones.
#
# *Hints:*
#
# 1. Defina la función, por ejemplo "masa_inv", y agregue una nueva columna al DataFrame de la siguiente forma:
#
# ```python
# zmumu.loc[:,'invM']=zmumu.apply(masa_inv,axis=1)
# ```
#
# 2. Para usar la función con la sintaxis anterior, debe definirla de forma que calcule usando los datos "renglón por renglón". Por ejemplo, una función que calcule el producto de la columna 1 con la columna 2:
#
# ```python
# def function (row):
#     return row['Column1']*row['Column2']
# ```

# %%
# SU CÓDIGO AQUÍ:

# %% [markdown]
# ## Z -> e e

# %% [markdown]
# ### EJERCICIO 1 b):
#
# - Realice el mismo ejercicio anterior, pero ahora con una muestra de eventos con dos electrones.
# - ¿Cuáles son las conclusiones?
# - ¿Qué diferencias principales encuentra entre esta muestra (dos electrones) y la anterior (dos muones)?
#
# *Hint:* Use ahora el archivo:
#
# ```python
# zee = pandas.read_csv('Zee_Run2011A.csv')
# ```

# %%
# SU CÓDIGO AQUÍ:
