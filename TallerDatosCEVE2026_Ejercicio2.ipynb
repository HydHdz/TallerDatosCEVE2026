# %% [markdown]
# CONCURSO DE ESTANCIAS DE VERANO EXPERIMENTALES 2026
#
# # TALLER DE ANÁLISIS DE DATOS
#
# # EJERCICIO 2 - SELECCIÓN BÁSICA DE EVENTOS

# %% [markdown]
# ## Datos a analizar
#
# Los datos fueron seleccionados de muestras primarias (Run2011A) para obtener el espectro general de eventos di-muónicos y di-electrónicos.
#
# Ver: https://opendata.cern.ch/record/545
#
# Primero descargamos los datos:

# %%
# !wget "https://opendata.cern.ch/record/545/files/Dimuon_SingleMu.csv"
# !wget "https://opendata.cern.ch/record/545/files/Dimuon_DoubleMu.csv"

# %% [markdown]
# ## Paquetes requeridos

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import math as m
# %matplotlib inline

# %% [markdown]
# ## Ejercicio 2, a):
#
# - Convertir las muestras "SingleMu" y "DoubleMu" a formato DataFrame. Visualice las columnas y obtenga la descripción estadística de algunas de las variables. ¿Cómo se comparan con las del Ejercicio 1?
# - Combinar ambas muestras. Las muestras "SingleMu" y "DoubleMu" se extrajeron del mismo dataset. Es posible combinarlas usando la función de PANDAS "concat". **ADVERTENCIA**: al provenir del mismo dataset, pueden haber evento duplicados luego de la concatenación. Asegúrese de que los eventos (*"Event"*) repetidos que provengan de la misma corrida (*"Run"*) sean removidos antes de realizar el análisis.
#
# *Hints:*
#
# 1. Para concatenar dos dataframes (df1, df2), usar:
# ```python
# new_df = pandas.concat([df1,df2],axis=0)
# ```
#
# 2. Para eliminar renglones duplicados con los mismos valores en la columna 1 y columna 2:
# ```python
# clean_df=new_df.drop_duplicates(subset=['Column1', 'Column2'], keep='first')
# ```

# %%
# SU CÓDIGO AQUÍ:

# %% [markdown]
# ## Ejercicio 2, b):
#
# - Calcule la masa invariante del sistema di-muónico y agregue la columna correspondiente. Grafique el resultado. ¿Qué puede observar en comparación a la distribución encontrada con las muestras del ejercicio 1?
# - Realice una selección básica de eventos. ¿Qué cortes puede aplicar para limpiar la muestra y obtener eventos que provengan de una desintegración del bosón Z? ¿Cuáles son los valores característicos esperados para **p_t**? ¿**Eta**? ¿**Carga**?
# - Grafique la masa invariante de la muestra luego de la selección y compare con la original. ¿Logra reconstruir la masa del Z?
#
#
# *Hints:*
#
# Para hacer un filtrado en base a una condición usar: `df_withCut = df['condición']`.
#
# Por ejemplo, para filtrar datos del DataFrame **'df'** donde la variable **'var'** sea mayor que 10:
# ```python
# df_withCut = df[df['var']>10]
# ```

# %%
# SU CÓDIGO AQUÍ:
